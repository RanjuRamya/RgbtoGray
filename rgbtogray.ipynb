# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img=mpimg.imread('Pics\OIP.jpg')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\O'
# <>:1: SyntaxWarning: invalid escape sequence '\O'
# C:\Users\91735\AppData\Local\Temp\ipykernel_16784\539370908.py:1: SyntaxWarning: invalid escape sequence '\O'
#   img=mpimg.imread('Pics\OIP.jpg')

# %%
img=mpimg.imread('Pics\OIP.jpg') #converting image to numpyarray
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\O'
# <>:1: SyntaxWarning: invalid escape sequence '\O'
# C:\Users\91735\AppData\Local\Temp\ipykernel_16784\3446835006.py:1: SyntaxWarning: invalid escape sequence '\O'
#   img=mpimg.imread('Pics\OIP.jpg') #converting image to numpyarray

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (476, 474, 3)

# %%
print(img)
# Out:
# [[[ 84  80  94]
#   [ 82  78  92]
#   [ 80  76  90]
#   ...
#   [163 175 171]
#   [163 175 171]
#   [163 175 171]]
#
#  [[ 84  80  94]
#   [ 82  78  92]
#   [ 80  76  90]
#   ...
#   [161 173 171]
#   [163 173 172]
#   [162 174 172]]
#
#  [[ 84  80  94]
#   [ 82  78  92]
#   [ 80  76  90]
#   ...
#   [148 157 162]
#   [158 165 171]
#   [157 166 171]]
#
#  ...
#
#  [[118 108 119]
#   [115 105 114]
#   [110 101 104]
#   ...
#   [196 201 107]
#   [165 175  50]
#   [162 177  34]]
#
#  [[125 114 128]
#   [121 111 122]
#   [114 108 112]
#   ...
#   [218 224 138]
#   [170 184  63]
#   [168 185  47]]
#
#  [[130 119 135]
#   [126 116 127]
#   [118 111 118]
#   ...
#   [223 231 148]
#   [172 185  67]
#   [168 186  50]]]

# %%
img_plot=plt.imshow(img)
plt.show()

# %%
pip install --upgrade --force-reinstall Pillow
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ...
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#     --------------------------------------- 0.1/2.6 MB 812.7 kB/s eta 0:00:04
#    -- ------------------------------------- 0.2/2.6 MB 1.5 MB/s eta 0:00:02
#    ------- -------------------------------- 0.5/2.6 MB 3.5 MB/s eta 0:00:01
#    ------------------------ --------------- 1.6/2.6 MB 7.7 MB/s eta 0:00:01
#    ---------------------------------------  2.5/2.6 MB 10.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 10.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: Pillow
#     Found existing installation: pillow 10.3.0
#     Uninstalling pillow-10.3.0:
#       Successfully uninstalled pillow-10.3.0
# ...
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\91735\AppData\Local\Programs\Python\Python312\Lib\site-packages\~il'.
# ...

# %%
from PIL import Image

# %%
img=Image.open('Pics\OIP.jpg') #reduce dimension of image
img_resized=img.resize((200,200))
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\O'
# <>:1: SyntaxWarning: invalid escape sequence '\O'
# C:\Users\91735\AppData\Local\Temp\ipykernel_16784\1192677280.py:1: SyntaxWarning: invalid escape sequence '\O'
#   img=Image.open('Pics\OIP.jpg') #reduce dimension of image

# %%
img_resized.save('floer_resized.jpg')

# %%
img_res=mpimg.imread('floer_resized.jpg')

img_res_plot=plt.imshow(img_res)
plt.show()

# %%
img_res=mpimg.imread('floer_resized.jpg')#imread converts img to numpy array

img_res_plot=plt.imshow(img_res)
plt.show()

# %%
print(img_res.shape)
# Out:
# (200, 200, 3)

# %%
#convert rgb to grayscale using opencv
#cv computer vision


import cv2

# %%
img=cv2.imread('floer_resized.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
#img shape
img.shape
# Out:
# (200, 200, 3)

# %%
grayscale_image=cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape #color channel is 1
# Out:
# (200, 200)

# %%
cv2.imshow('',grayscale_image)
cv2.waitKey(0)
# Out:
# -1

# %%
cv2.imwrite('foer_gray.jpg',grayscale_image)
# Out:
# True
